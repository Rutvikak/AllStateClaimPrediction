# %% [markdown]
# # Allstate Claim Prediction
#
# ## Goal of this activity:
# **To better predict Bodily Injury Liability Insurance claim payments based on the characteristics of the insured customer’s vehicle.**
#
# ### This dataset is derived from Kaggal's one of the competitions.
# Prediction of a claim amount is one of the crucial steps in the claim settlement process. As the time taken in this process is related to customer satisfaction, the aim of the insurance company is to reduce the time required for settling all claims by automating the process of claim amount generation using ML.
# Dataset consists of registered claims with the company. Dataset has data from years - 2005 to 2007.

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading Dataset
# Loading dataset, which is downloaded from Kaggal site, consists of observations from years - 2005 to 2007.

# %%
df = pd.read_csv(r'C:\Rutvika\BrainStation\CapstoneProject\AllstateClaimPredictionChallenge\DataSets\train_set\train_set.csv', index_col=0, low_memory=False)
df.head()
# Out:
#         Household_ID  Vehicle  Calendar_Year  Model_Year Blind_Make  \
# Row_ID
# 1                  1        3           2005        2005          K
# 2                  2        2           2005        2003          Q
# 3                  3        1           2005        1998         AR
# 4                  3        1           2006        1998         AR
# 5                  3        2           2005        2001          D
#
#        Blind_Model Blind_Submodel Cat1 Cat2 Cat3  ...      Var5      Var6  \
# Row_ID                                            ...
# 1             K.78         K.78.2    D    C    F  ...  1.008912  0.261040
# 2             Q.22         Q.22.3    B    C    A  ...  1.240851  0.432987
# 3            AR.41        AR.41.1    B    ?    A  ... -0.971487 -1.405797
# 4            AR.41        AR.41.1    B    ?    A  ... -0.971487 -1.405797
# 5             D.20         D.20.0    J    C    B  ...  0.812656  2.112691
#
# ...

# %% [markdown]
#  Whole dataset consists of 13184290 rows and 34 columns.

# %%
df.shape
# Out:
# (13184290, 34)

# %%
print(f"{round(df[df['Claim_Amount'] <= 0].shape[0] / df.shape[0],2)}% of observations having zeros in target feature.")
# Out:
# 0.99% of observations having zeros in target feature.

# %% [markdown]
# In data there are 99% of the claim values are zeros, it seems that the rejection ratio of claim rejection is high. The aim of this project is to predict the claim amount, so removing rows with zero values for further evaluation.

# %%
# Considering only non-zero values further calculations
df_sample = df[df['Claim_Amount'] > 0]

# %% [markdown]
# After removing rows with zeros in claim amount the shape of the data is:

# %%
df_sample.shape
# Out:
# (95605, 34)

# %% [markdown]
# **Saving data for future analysis after removing zeroes from claim amount.**

# %%
df_sample.to_csv(r'C:\Rutvika\BrainStation\CapstoneProject\AllstateClaimPredictionChallenge\DataSets\NewDataSet\sample_final.csv')
